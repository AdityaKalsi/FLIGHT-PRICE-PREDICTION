# %%
import pandas as pd
import numpy as np

# %%
import os 


flights = pd.read_csv(r'C:\Users\Aditya kalsi\Downloads\Flight Prediction Project\Data\flight_price.csv')
flights.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flights.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flights.duplicated().sum()
# Out:
# 220

# %% [markdown]
# ### Checking if the values are genuinely duplicated or not

# %%
(
    flights
    .loc[flights.duplicated()]
    .sort_values(['Airline','Date_of_Journey','Source','Destination'])
)
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 9848    Air India      01/03/2019  Banglore   New Delhi
# 8168    Air India      03/03/2019  Banglore   New Delhi
# 9913    Air India       1/04/2019   Kolkata    Banglore
# 5042    Air India       1/05/2019   Kolkata    Banglore
# 6377    Air India       1/05/2019   Kolkata    Banglore
# ...           ...             ...       ...         ...
# 9216  Jet Airways       9/06/2019     Delhi      Cochin
# 7502     SpiceJet      03/03/2019  Banglore   New Delhi
# 2870     SpiceJet      24/03/2019  Banglore   New Delhi
# 3711     SpiceJet      24/03/2019  Banglore   New Delhi
# 5470      Vistara      24/03/2019  Banglore   New Delhi
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 9848  BLR → BOM → AMD → DEL    08:50  23:55 02 Mar   39h 5m     2 stops
# 8168              BLR → DEL    21:10         23:55   2h 45m    non-stop
# 9913  CCU → DEL → COK → BLR    10:00  01:20 02 Apr  15h 20m     2 stops
# ...

# %% [markdown]
# - The duplicated values are genuinely duplicates

# %% [markdown]
# ## Detailed Analysis

# %% [markdown]
# -
# -

# %% [markdown]
# ### Airline

# %%
(
    flights
    .Airline
    .unique()
)
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
(
    flights
    .Airline
    .str.replace(' Premium economy','')
    .str.replace(' Business','')
    .str.title()
    .unique()
)
# Out:
# array(['Indigo', 'Air India', 'Jet Airways', 'Spicejet',
#        'Multiple Carriers', 'Goair', 'Vistara', 'Air Asia', 'Trujet'],
#       dtype=object)

# %%
(
    flights
    .assign(**{
        col : flights[col].str.strip()
        for col in flights.select_dtypes(include= 'O').columns
    })
)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# ## Date of Journey

# %%
pd.to_datetime(flights.Date_of_Journey,dayfirst = True)
# Out:
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10683, dtype: datetime64[ns]

# %% [markdown]
# ## Source

# %%
(
    flights
    .Source
    .unique()
)
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
(
    flights
    .Destination
    .unique()
)
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %% [markdown]
# ## Dep Time

# %% [markdown]
# - There might be certain speacial characters instead of semicolon so will have to check for all those errors

# %%
(
    flights
    .Dep_Time
    .str.contains('^[0-9]:')
    .sum()
)
# Out:
# 0

# %%
pd.to_datetime(flights.Dep_Time).dt.time
# Out:
# C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_5016\1056054517.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(flights.Dep_Time).dt.time
# 0        22:20:00
# 1        05:50:00
# 2        09:25:00
# 3        18:05:00
# 4        16:50:00
#            ...
# 10678    19:55:00
# 10679    20:45:00
# 10680    08:20:00
# 10681    11:30:00
# 10682    10:55:00
# Name: Dep_Time, Length: 10683, dtype: object

# %%
(
    flights
    .Arrival_Time
    .str.split(" ",n=1)
    .str.get(1)
    .unique()
)
# Out:
# array(['22 Mar', nan, '10 Jun', '13 Mar', '02 Mar', '10 May', '04 Mar',
#        '13 Jun', '28 May', '19 Mar', '07 May', '02 Jun', '16 Jun',
#        '19 May', '16 May', '28 Jun', '02 May', '28 Mar', '19 Jun',
#        '04 Apr', '25 Mar', '07 Mar', '25 Jun', '07 Jun', '25 May',
#        '13 May', '16 Mar', '22 May', '10 Apr', '04 Jun', '20 May',
#        '28 Apr', '25 Apr', '10 Mar', '19 Apr', '13 Apr', '02 Apr',
#        '23 Mar', '22 Apr', '11 May', '07 Apr', '03 May', '08 Mar',
#        '03 Mar', '05 Mar', '22 Jun', '04 May', '26 May', '16 Apr',
#        '26 Jun', '29 May', '29 Jun', '29 Mar', '23 May', '17 Jun'],
#       dtype=object)

# %%
(
    flights
    .Arrival_Time
    .str.split(n = 1)
    .str.get(0)
)
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %% [markdown]
# ## Duration

# %%
(
    flights
    .Duration
    .loc[lambda ser: ~ser.str.contains('m')]
)
# Out:
# 2        19h
# 18       23h
# 33       22h
# 44       12h
# 53        3h
#         ...
# 10591    23h
# 10638    14h
# 10639    38h
# 10673    15h
# 10680     3h
# Name: Duration, Length: 1031, dtype: object

# %%
(
    flights
    .Duration
    .loc[lambda ser: ~ser.str.contains('h')]
)
# Out:
# 6474    5m
# Name: Duration, dtype: object

# %%
flights.loc[[6474]]
# Out:
#         Airline Date_of_Journey  Source Destination                  Route  \
# 6474  Air India       6/03/2019  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD
#
#      Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price
# 6474    16:50        16:55       5m     2 stops         No info  17327

# %%
def convert_to_minutes(ser):
	return (
		ser
		.str.split(" ", expand=True)
		.set_axis(["hour", "minute"], axis=1)
		.assign(
			hour=lambda df_: (
				df_
				.hour
				.str.replace("h", "")
				.astype(int)
				.mul(60)
			),
			minute=lambda df_: (
				df_
				.minute
				.str.replace("m", "")
				.fillna("0")
				.astype(int)
			)
		)
		.sum(axis=1)
	)

# %%
(
    flights
    .Total_Stops
    .unique()
)
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
(
    flights
    .Total_Stops
    .replace('non-stop','0')
    .str.replace(' stops?','',regex = True)
    .unique()
)
# Out:
# array(['0', '2', '1', '3', nan, '4'], dtype=object)

# %%
(
    flights
    .Additional_Info
    .str.replace('No info','No Info')
    .unique()
)
# Out:
# array(['No Info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
(
    flights
    .Arrival_Time

)
# Out:
# 0        01:10 22 Mar
# 1               13:15
# 2        04:25 10 Jun
# 3               23:30
# 4               21:35
#              ...
# 10678           22:25
# 10679           23:20
# 10680           11:20
# 10681           14:10
# 10682           19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
pd.to_datetime(flights.Arrival_Time).dt.time
# Out:
# C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_5016\2994693450.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(flights.Arrival_Time).dt.time
# 0        01:10:00
# 1        13:15:00
# 2        04:25:00
# 3        23:30:00
# 4        21:35:00
#            ...
# 10678    22:25:00
# 10679    23:20:00
# 10680    11:20:00
# 10681    14:10:00
# 10682    19:15:00
# Name: Arrival_Time, Length: 10683, dtype: object

# %% [markdown]
# ## Cleaning function

# %%
def clean(df):
	return (
		df
		.drop(index=[6474])
		.drop_duplicates()
		.assign(**{
			col: df[col].str.strip()
			for col in df.select_dtypes(include="O").columns
		})
		.rename(columns=str.lower)
		.assign(
			airline=lambda df_: (
				df_
				.airline
				.str.replace(" Premium economy", "")
				.str.replace(" Business", "")
				.str.title()
            ),
            date_of_journey=lambda df_: pd.to_datetime(df_.date_of_journey, dayfirst=True),
            dep_time=lambda df_: pd.to_datetime(df_.dep_time).dt.time,
			arrival_time=lambda df_: pd.to_datetime(df_.arrival_time).dt.time,
			duration=lambda df_: df_.duration.pipe(convert_to_minutes),
            total_stops=lambda df_: (
				df_
				.total_stops
				.str.replace("non-stop", "0")
				.str.replace(" stops?", "", regex=True)
				.pipe(lambda ser: pd.to_numeric(ser))
            ),
            additional_info=lambda df_: df_.additional_info.replace("No info", "No Info")
        )
        .drop(columns = 'route')
    )

# %%
flights_cleaned = clean(flights)
flights_cleaned
# Out:
# C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_5016\2566821795.py:20: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dep_time=lambda df_: pd.to_datetime(df_.dep_time).dt.time,
# C:\Users\Aditya kalsi\AppData\Local\Temp\ipykernel_5016\2566821795.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   arrival_time=lambda df_: pd.to_datetime(df_.arrival_time).dt.time,
#            airline date_of_journey    source destination  dep_time  \
# 0           Indigo      2019-03-24  Banglore   New Delhi  22:20:00
# 1        Air India      2019-05-01   Kolkata    Banglore  05:50:00
# 2      Jet Airways      2019-06-09     Delhi      Cochin  09:25:00
# ...

# %%
from sklearn.model_selection import train_test_split

flights_final = flights_cleaned.sample(1000)

X = flights_final.drop(['price'],axis = 1)
y = flights_final['price']

X_, X_test, y_, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_, y_, test_size=0.33, random_state=42)

# %%
import os 

project_dir = r'C:\Users\Aditya kalsi\Downloads\Flight Prediction Project\Data'

def file_transfer(X,y,name):
    file_name = f"{name}.csv"
    file_path = os.path.join(project_dir,file_name)

    X.join(y).to_csv(file_path,index = False)

    return pd.read_csv(file_path).head()

# %%
file_transfer(X_train,y_train,'train')
# Out:
#        airline date_of_journey    source destination  dep_time arrival_time  \
# 0  Jet Airways      2019-03-12  Banglore   New Delhi  05:45:00     20:20:00
# 1  Jet Airways      2019-05-24   Kolkata    Banglore  21:10:00     10:05:00
# 2  Jet Airways      2019-05-18   Kolkata    Banglore  08:25:00     08:15:00
# 3  Jet Airways      2019-05-15   Kolkata    Banglore  18:55:00     10:05:00
# 4  Jet Airways      2019-06-06     Delhi      Cochin  11:00:00     14:15:00
#
#    duration  total_stops              additional_info  price
# 0       875          1.0                      No Info  13817
# 1       775          1.0  In-flight meal not included   9663
# 2      1430          1.0  In-flight meal not included   9663
# 3       910          1.0  In-flight meal not included   9663
# 4       195          0.0                      No Info   9564

# %%
file_transfer(X_val, y_val, "val")
# Out:
#        airline date_of_journey    source destination  dep_time arrival_time  \
# 0    Air India      2019-03-03  Banglore   New Delhi  00:30:00     23:55:00
# 1      Vistara      2019-04-01   Kolkata    Banglore  17:00:00     22:55:00
# 2    Air India      2019-05-27     Delhi      Cochin  22:00:00     19:15:00
# 3    Air India      2019-03-18    Mumbai   Hyderabad  19:30:00     20:45:00
# 4  Jet Airways      2019-05-06   Kolkata    Banglore  14:05:00     19:50:00
#
#    duration  total_stops              additional_info  price
# 0      1405          1.0                      No Info  10394
# 1       355          1.0                      No Info   8977
# 2      1275          2.0                      No Info  10231
# 3        75          0.0                      No Info   2050
# 4       345          1.0  In-flight meal not included  10844

# %%
file_transfer(X_test,y_test,'test')
# Out:
#              airline date_of_journey   source destination  dep_time  \
# 0        Jet Airways      2019-05-06  Kolkata    Banglore  06:30:00
# 1  Multiple Carriers      2019-06-15    Delhi      Cochin  10:20:00
# 2          Air India      2019-05-12  Kolkata    Banglore  10:00:00
# 3          Air India      2019-03-27    Delhi      Cochin  21:30:00
# 4          Air India      2019-05-24  Kolkata    Banglore  05:50:00
#
#   arrival_time  duration  total_stops additional_info  price
# 0     18:15:00       705          1.0         No Info  14781
# 1     01:30:00       910          1.0         No Info   6795
# 2     05:25:00      1165          2.0         No Info  14634
# 3     19:15:00      1305          2.0         No Info   8665
# 4     13:15:00       445          2.0         No Info   7662

# %%
flights_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10462 entries, 0 to 10682
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   airline          10462 non-null  object
#  1   date_of_journey  10462 non-null  datetime64[ns]
#  2   source           10462 non-null  object
#  3   destination      10462 non-null  object
#  4   dep_time         10462 non-null  object
#  5   arrival_time     10462 non-null  object
#  6   duration         10462 non-null  int64
#  7   total_stops      10461 non-null  float64
#  8   additional_info  10462 non-null  object
#  9   price            10462 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 899.1+ KB
